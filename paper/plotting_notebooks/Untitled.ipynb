# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import datasets

# %%
webnlg_full_embedded = datasets.load_dataset("json", data_files="../../outputs/dataset_embeddings/allneg_alldatasets_bs160/webnlg_all_embed.jsonl", split="train")
# Out:
# Using custom data configuration default-dc336fe9ca0f92f6
# Reusing dataset json (/home/teven/.cache/huggingface/datasets/json/default-dc336fe9ca0f92f6/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b)

# %%
webnlg_full_embedded[3]
# Out:
# {'text': 'Malaysian Chinese and Malaysian Malay are ethnic groups of Malaysia, where asam pedas is a local food. The dish comes from the Sumatra and Malay Peninsula regions.',
#  'triples': [['asam pedas', 'country', 'Malaysia'],
#   ['Malaysia', 'ethnic group', 'Malaysian Chinese'],
#   ['Malaysia', 'ethnic group', 'Malaysian Malay'],
#   ['asam pedas', 'indigenous to', 'Sumatra and Malay Peninsula']],
#  'rdf_linearized': '[S] asam pedas [P] country [O] Malaysia [S] Malaysia [P] ethnic group [O] Malaysian Chinese [S] Malaysia [P] ethnic group [O] Malaysian Malay [S] asam pedas [P] indigenous to [O] Sumatra and Malay Peninsula ',
#  'rdf_mixed': '[S] asam pedas [P] country [O] Malaysia [S] Malaysia [P] ethnic group [O] Malaysian Chinese [S] Malaysia [P] ethnic group [O] Malaysian Malay [S] asam pedas [P] indigenous to [O] Sumatra and Malay Peninsula ',
# ...
